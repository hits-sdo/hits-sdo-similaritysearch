# %% [markdown]
# <a href="https://colab.research.google.com/github/hits-sdo/hits-sdo-similaritysearch/blob/byol_losses/search_byol/loss_experiments/tico_byol_train_pl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook to Intialize HITS-SDO self-similarity search environment
# - Run all cells to initalize environment, and restart runtime if prompted to use updated versions. You will need to rerun the cells again to ensure that all dependencies have been installed.

# %% [markdown]
# # Download and Unzip Data

# %%
# Download Data - Uncomment the one you want

# 171 with false yellow colors - https://drive.google.com/file/d/15C5spf1la7L09kvWXll2qt67Ec0rwLsY/view?usp=drive_link
# !gdown 15C5spf1la7L09kvWXll2qt67Ec0rwLsY


# 171 grayscale - https://drive.google.com/file/d/16WD0td1f5gx4yIIDkWWSTb-oZcezI1CU/view?usp=drive_link
# !gdown 16WD0td1f5gx4yIIDkWWSTb-oZcezI1CU


# Multiwavelength r:211 g:193 b:171 https://drive.google.com/file/d/1DMIatOmA4XcoWeW0oAUkZujx8YrhLkpY/view?usp=sharing
# !gdown 1DMIatOmA4XcoWeW0oAUkZujx8YrhLkpY
# Multiwavelength r:211 g:193 b:171active cycle extension https://drive.google.com/file/d/1-BPQpdQWNwZzoVpg3lQ143cr3_UPE36M/view?usp=sharing
# !gdown 1-BPQpdQWNwZzoVpg3lQ143cr3_UPE36M

# Multiwavelength r:304 g:211 b:171 https://drive.google.com/file/d/1Pts431S-fdSfJJ6pt79-fkNYazXqO9O7/view?usp=sharing
# !gdown 1Pts431S-fdSfJJ6pt79-fkNYazXqO9O7
# Multiwavelength r:304 g:211 b:171 active cycle extension https://drive.google.com/file/d/1Sbbgi6HzJkuCTUF8tJTLeddpGIjGXTcj/view?usp=sharing
# !gdown 1Sbbgi6HzJkuCTUF8tJTLeddpGIjGXTcj


# Multiwavelength r:335 g:193 b:94 https://drive.google.com/file/d/1v0IYSzwiQcHPcnSsTAeU7bI8c4310b35/view?usp=sharing
# !gdown 1v0IYSzwiQcHPcnSsTAeU7bI8c4310b35
# Multiwavelength r:335 g:193 b:94 active cycle extension https://drive.google.com/file/d/1uSt8BzpVj5GgM9SwSsDcQMEE4lv1uTJo/view?usp=sharing
# !gdown 1uSt8BzpVj5GgM9SwSsDcQMEE4lv1uTJo
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1DMIatOmA4XcoWeW0oAUkZujx8YrhLkpY
# To: /content/AIA211_193_171_Miniset.tar.gz
# 100% 121M/121M [00:00<00:00, 145MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-BPQpdQWNwZzoVpg3lQ143cr3_UPE36M
# To: /content/AIA211_193_171_Miniset_ext.tar.gz
# 100% 175M/175M [00:02<00:00, 70.6MB/s]

# %%
# Unzip file make them match the cell above

# 171 with false yellow colors
# !tar -zxf aia_171_color_1perMonth.tar.gz


# 171 grayscale
# !tar -zxf AIA171_Miniset_BW.tar.gz


# Multiwavelength r:211 g:193 b:171
# !tar -zxf AIA211_193_171_Miniset.tar.gz
# Multiwavelength r:211 g:193 b:171active cycle extension
# !tar -zxf AIA211_193_171_Miniset_ext.tar.gz


# Multiwavelength r:304 g:211 b:171
# !tar -zxf AIA304_211_171_Miniset.tar.gz
# Multiwavelength r:304 g:211 b:171 active cycle extension
aia_211_193_171/tiles
# 3.2M	AIA211_193_171_Miniset/./20110417_000002_aia_211_193_171
# 40K	AIA211_193_171_Miniset/./20150826_000000_aia_211_193_171/tile_meta_data
# 3.2M	AIA211_193_171_Miniset/./20150826_000000_aia_211_193_171/tiles
# 3.2M	AIA211_193_171_Miniset/./20150826_000000_aia_211_193_171
# 1.1G	AIA211_193_171_Miniset/.

# %% [markdown]
# # Clone repository

# %%
# Clone the repository from GitHub
# !git clone https://github.com/hits-sdo/hits-sdo-similaritysearch
# Out:
# Cloning into 'hits-sdo-similaritysearch'...
# remote: Enumerating objects: 911, done.
# remote: Counting objects: 100% (137/137), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 911 (delta 66), reused 47 (delta 47), pack-reused 774
# Receiving objects: 100% (911/911), 67.86 MiB | 23.83 MiB/s, done.
# Resolving deltas: 100% (428/428), done.

# %%
# %cd hits-sdo-similaritysearch/
# Out:
# /content/hits-sdo-similaritysearch

# %% [markdown]
# # Switch to Desired Branch

# %%
# Switch to the desired branch with requirements.txt
# !git checkout byol_losses
# Out:
# Branch 'byol_losses' set up to track remote branch 'byol_losses' from 'origin'.
# Switched to a new branch 'byol_losses'

# %%
# Confirm that branch is up to date
# !git log --oneline
# Out:
# 8295769 (HEAD -> byol_losses, origin/byol_losses) Fix wrong dataset being used during inference
# 9a0e6b1 Fix typo on else statement
# 552b238 removed the wandb token and make strides quick
# 84301bf Removed joint cos and contrast loss because cos is contained inside contrast
# 4f5a77b remove wandb token
# 53cfb68 Changed default stride to run fast runs
# b958e0d Add the possibility to run with different losses
# 2d8884c (origin/byol-embeddings-analysis) Merge remote-tracking branch 'origin/main' into byol-embeddings-analysis
# 94a1c98 Tested contrastive loss
# 5ed8e29 Fixed Lightning mistakes
# 49ecdf4 Test notebook to use lightning
# 1ddbb30 (origin/main, origin/HEAD, main) Merge pull request #13 from hits-sdo/ss_dataloader
# d12f080 updated the notebook to accommodate multi-wavelength images
# 1342fde included multi_wl arg
# 8af3f47 updated to accommodate multi-wavelength filenaming
# 38e1ef2 Added code (commented out) for saving model in wandb
# 01dee0a Fixed the calculation of the average loss during an epoch and logged the plot of the 2D embeddings
# 8193562 Merge pull request #12 from hits-sdo/byol-embeddings-analysis
# feba813 Added and tested expanded dataset
# 5a1debf Add extended multi-wavelength datasets
# 4d28003 Merge pull request #11 from hits-sdo/byol-embeddings-analysis
# e1966f7 Test run with new multi-channel data
# 626a955 Add data type to wandb config and set datapaths
# 4db3fc2 Add different data alternatives to check
# 22abf42 Add multi-wavelength downloads to notebooks
# 2581166 Add seed parameter for reproducibility
# ca5ce2f Updated to new dataset file name and add embeddings plot
# d2b58c7 Added test to make sure that double augmentation also produces different images
# 2534ea6 change dataset to return zero when augmentation is 'none'
# f90d9ae Merge branch 'byol-embeddings-analysis' of https://github.com/hits-sdo/hits-sdo-similaritysearch into byol-embeddings-analysis
# 6804358 Changed dataset augmentation options to none, single, and double
# 0627812 rename database to dataset to be consistent with pytorch conventions
# b73b1d7 update TODO, cleaned up the code further
# d91a4e6 Tested similarity search on Validation Data.
# 76572d4 edited to-do list. discussed make_dot but not implemented
# 1c8bae0 Fixed ModuleNotFound error
# 982a660 Merge pull request #10 from hits-sdo/search-byol-experiment-2
# 02a851e Don't drop last batch, even if incomplete
# a75f541 Update number of workers to take advantage of colab pro plus
# cf69bd9 updated to-do list
# ecaffb7 added data subset
# d15287f updated the example with path_to_data
# 1e54cab Cleaned up code more
# e5c0f7d added path_to_data as an argument
# f6d2dfb Created using Colaboratory
# 7e96a0d Added import to proper area
# 1a50cda Cleaned up code
# 44cb8bd Created using Colaboratory
# 61475e6 Markdown text for cells
# 6e36ce6 trial run with a batch size of 1024
# 65eb59d added image_size argument and an example
# b0a7ff2 added supeimage functionality is custom collate function
# 372396e (origin/search-byol-experiment-2) Added projection and prediction head output sizes to parameters
# 5f9ad14 Merge pull request #9 from hits-sdo/experimentation-1
# 80c6690 fixed the problem with the run for superimage fill_type
# c76153b added entity name and updated project name in wandb init
# 437227d Successfully implemented 'SuperImage' fill_type functionality in collate fn with Team Sunbird
# 71e1f41 Reduced the scheduler start to 0.1 saw huge increase of performance
# 91bb975 Higher learning rate experiment 1
# 3165bf0 add path to file for superimage inputs in collate function
# a6c0a1b Add scheduler and hyperparameters to name
# 90fd5a9 Added more hyperparameters.
# 3bf0588 implemented nested collate fn
# 4f5b4cb Tags
# 680ddd2 Created using Colaboratory
# 9bc18d1 Expansion wandb init
# 8322153 added wandb log
# d67150f Update branch checkout and "open in colab" button
# 3138a92 Merge pull request #8 from hits-sdo/byol-wandb
# c371570 Merge pull request #7 from hits-sdo/ss_dataloader
# 3814d7f Merge pull request #5 from hits-sdo/data_removal
# 7b7d5fa Merge branch 'main' into data_removal
# 58f41c3 argument is now list of tuples
# cd7d8ec moved to experiments folder
# 0fc1923 moved to notes folder
# 35973b9 Merge pull request #6 from hits-sdo/byol-dataset_doc
# b95a0f9 Add wandb logging
# 5e18de2 update checkout branch
# 22d840d Update open in colab button
# 491c6f9 Added documentation to test and database classes
# 8b5c1a7 Delete Copy_of_simsiam_example_notebook_HITS.ipynb
# e510752 Sunbird Collate function successfully implemented
# 8be46b9 moved and renamed
# 5542e94 Created using Colaboratory
# 25c05e8 Added numpy to torch-tensor conversion
# b45f603 Add ipywidgets to requirements
# 38b4e5e Remove binary data
# bbcf0f0 Merge remote-tracking branch 'origin/main' into byol-training_pipeline
# 7e479ef Merge branch 'ss_dataloader' of https://github.com/hits-sdo/hits-sdo-similaritysearch into ss_dataloader
# b2f7e26 added image normalization
# b4a4c51 fixed sunbird_collate rendering issue
# b7be3c9 Merge branch 'ss_dataloader' of https://github.com/hits-sdo/hits-sdo-similaritysearch into ss_dataloader
# 7e19d15 team sunbird started custom collate function
# e770817 Removed datatype casting
# 6e25301 team yellow started custom collate function
# 3ac3080 Fixed and annotated progress bars
# f7937e2 added default datatype and made it single float
# 570ff76 Add tqdm bars to training notebook
# f666699 Add dataset stride to work with even smaller sets
# 899150b Merge remote-tracking branch 'origin/byol-augmentation' into byol-training_pipeline
# 66b4624 test and ensure that dimensions are chanels first
# cfb9fad Debugging and creating collate function.
# 570365f Update data loader in byol_train
# cb8037b fix opencv pip repository in requirements
# 0db1aa6 add a version requirement to opencv
# 0dd5485 Merge branch 'byol-training_pipeline' of https://github.com/hits-sdo/hits-sdo-similaritysearch into byol-training_pipeline
# 4183c2c Add opencv to requirements
# 7b7e31d Add link to colab
# e99626e Re-commit training notebook
# 464356e Initalize BYOL training notebook
# f6a7bcf Rename database class and add augmentations
# ab131e7 Modified custom collate function
# e8e2abd Update 5-24-23_NOTES.md
# 27ec654 added note
# 794656d Created custom collate function
# 7c19761 Merge branch 'ss_dataloader' of https://github.com/hits-sdo/hits-sdo-similaritysearch into ss_dataloader
# 32ad99d Co-authored-by: Jasper <jasperdoan@users.noreply.github.com> Co-authored-by: Cameron Wolff <camwolff02@users.noreply.github.com> Co-authored-by: max9001 <max9001@users.noreply.github.com>
# 3f03231 Merge pull request #2 from hits-sdo/byol-loader
# 6b23428 Initialize database and its test suite
# d83a4b3 Add npy files to gitignore
# 229d355 Success with Stitch Parent Image
# c5d6eb7 5-24-23 Notes
# d1dcfa0 working towards successful parent image
# 89d7a5f Added .jpg compatibility to image_utils
# 4e0d534 Team Sunbird: Trained model, generated embeddings, and plotted image clusters
# 9d7827a checking tensor dimensions and values
# 2c6dde6 installed packages under requirements.txt
# 6cd8812 removed unnecessary code cell
# 9956dc5 moved to search_simsiam
# 53f9f34 Created using Colaboratory by team sunbird
# e47b776 team-sunbird used stitch_adj_images to fill voids in two augmented views
# acdcd3c Merge pull request #1 from hits-sdo/initialization
# b6b76a7 Make main the default branch in the notebook setup
# 3e41ea2 Added download to setup notebook
# 7135c8a replaced 'search-utils' with 'search_utils'
# 8c2014c replaced '-' with '_' in module names
# 97a1002 added search_utils to sys.path
# dd9c215 added search-utils to sys.path
# 0702056 renamed folder module utils to search-utils
# 68990e6 renamed folder module utils to search-utils
# 23f7e1e renamed folder module utils to search-utils
# cae0aef renamed folder module utils to search-utils
# 341a9e8 two augmentations from same source image Co-authored-by: Jasper <jasperdoan@users.noreply.github.com> Co-authored-by: max9001 <max9001@users.noreply.github.com> Co-authored-by: Matin Qurbanzadeh <MatinQurban@users.noreply.github.com> Co-authored-by: ThomasP677 <ThomasP677@users.noreply.github.com> Co-authored-by: Cameron Wolff <camwolff02@users.noreply.github.com> Co-authored-by: agomez225 <agomez225@users.noreply.github.com>
# 290033d two different augmentations from same source image
# 49b7753 Merge branch 'initialization' of https://github.com/hits-sdo/hits-sdo-similaritysearch into initialization
# 1561b9f Removed unnecessary commits in notebook
# 4c65ec8 Merge branch 'initialization' of https://github.com/hits-sdo/hits-sdo-similaritysearch into initialization
# 90e272f corrected bug in file length calculation
# d357801 converted utils folder to module
# 4c97358 moved to utils folder
# 3d9abed Wrote the setup for dependencies in requirements.txt
# 060fc49 Merge branch 'initialization' of https://github.com/hits-sdo/hits-sdo-similaritysearch into initialization
# 2c267cd added image reader and super image generator
# b523fa6 Merge branch 'initialization' of https://github.com/hits-sdo/hits-sdo-similaritysearch into initialization
# c88d5fe Add intialization Notebook
# b07d5d7 added notebook to demonstrate the entire experiment
# 86e9956 added pickle files of monochrome AIA171 tiles
# 2703ad8 added opencv and matplotlib
# 0232721 added opencv and matplotlib
# 87cda42 Add conda environment and pip requirement files
# 25d2b32 convert folders to modules
# 3fcfe3a convert simsiam folder to module
# 753e232 Add augmentation dictionary file
# 5244ae1 Initial commit

# %% [markdown]
# # Install all necesary packages into environment

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/hits-sdo/hits-sdo-packager.git@pip_nodata (from -r requirements.txt (line 13))
#   Cloning https://github.com/hits-sdo/hits-sdo-packager.git (to revision pip_nodata) to /tmp/pip-req-build-nuu6nhn8
#   Running command git clone --filter=blob:none --quiet https://github.com/hits-sdo/hits-sdo-packager.git /tmp/pip-req-build-nuu6nhn8
#   Running command git checkout -b pip_nodata --track origin/pip_nodata
#   Switched to a new branch 'pip_nodata'
#   Branch 'pip_nodata' set up to track remote branch 'pip_nodata' from 'origin'.
#   Resolved https://github.com/hits-sdo/hits-sdo-packager.git to commit eecfbe18e34961276a5e2aef3a8b2319b796ca9c
#   Preparing metadata (setup.py) ... done
# Collecting lightning (from -r requirements.txt (line 6))
#   Downloading lightning-2.0.3-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 21.5 MB/s eta 0:00:00
# Collecting lightly (from -r requirements.txt (line 7))
#   Downloading lightly-1.4.8-py3-none-any.whl (619 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.4/619.4 kB 48.1 MB/s eta 0:00:00
# Collecting sunpy (from -r requirements.txt (line 8))
#   Downloading sunpy-5.0.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 86.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 9)) (1.5.3)
# Collecting wandb (from -r requirements.txt (line 10))
#   Downloading wandb-0.15.4-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 92.8 MB/s eta 0:00:00
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 11)) (7.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 12)) (4.7.0.72)
# Requirement already satisfied: Jinja2<5.0 in /usr/local/lib/python3.10/dist-packages (from lightning->-r requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: PyYAML<8.0 in /usr/local/lib/python3.10/dist-packages (from lightning->-r requirements.txt (line 6)) (6.0)
# Collecting arrow<3.0,>=1.2.0 (from lightning->-r requirements.txt (line 6))
#   Downloading arrow-1.2.3-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4<6.0,>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from lightning->-r requirements.txt (line 6)) (4.11.2)
# Requirement already satisfied: click<10.0 in /usr/local/lib/python3.10/dist-packages (from lightning->-r requirements.txt (line 6)) (8.1.3)
# Collecting croniter<1.4.0,>=1.3.0 (from lightning->-r requirements.txt (line 6))
#   Downloading croniter-1.3.15-py2.py3-none-any.whl (19 kB)
# Collecting dateutils<2.0 (from lightning->-r requirements.txt (line 6))
#   Downloading dateutils-0.6.12-py2.py3-none-any.whl (5.7 kB)
# Collecting deepdiff<8.0,>=5.7.0 (from lightning->-r requirements.txt (line 6))
#   Downloading deepdiff-6.3.0-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 kB 8.4 MB/s eta 0:00:00
# Collecting fastapi<0.89.0,>=0.69.0 (from lightning->-r requirements.txt (line 6))
#   Downloading fastapi-0.88.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec<2024.0,>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from lightning->-r requirements.txt (line 6)) (2023.4.0)
# Collecting inquirer<5.0,>=2.10.0 (from lightning->-r requirements.txt (line 6))
#   Downloading inquirer-3.1.3-py3-none-any.whl (18 kB)
# Collecting lightning-cloud>=0.5.34 (from lightning->-r requirements.txt (line 6))
#   Downloading lightning_cloud-0.5.36-py3-none-any.whl (562 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 562.4/562.4 kB 51.1 MB/s eta 0:00:00
# Collecting lightning-utilities<2.0,>=0.7.0 (from lightning->-r requirements.txt (line 6))
#   Downloading lightning_utilities-0.8.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: numpy<3.0,>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from lightning->-r requirements.txt (line 6)) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from lightning->-r requirements.txt (line 6)) (23.1)
# Requirement already satisfied: psutil<7.0 in /usr/local/lib/python3.10/dist-packages (from lightning->-r requirements.txt (line 6)) (5.9.5)
# Requirement already satisfied: pydantic<4.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from lightning->-r requirements.txt (line 6)) (1.10.7)
# Collecting python-multipart<2.0,>=0.0.5 (from lightning->-r requirements.txt (line 6))
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: requests<4.0 in /usr/local/lib/python3.10/dist-packages (from lightning->-r requirements.txt (line 6)) (2.27.1)
# Requirement already satisfied: rich<15.0,>=12.3.0 in /usr/local/lib/python3.10/dist-packages (from lightning->-r requirements.txt (line 6)) (13.3.4)
# Collecting starlette (from lightning->-r requirements.txt (line 6))
#   Downloading starlette-0.28.0-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.9/68.9 kB 8.5 MB/s eta 0:00:00
# Collecting starsessions<2.0,>=1.2.1 (from lightning->-r requirements.txt (line 6))
#   Downloading starsessions-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: torch<4.0,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from lightning->-r requirements.txt (line 6)) (2.0.1+cu118)
# Collecting torchmetrics<2.0,>=0.7.0 (from lightning->-r requirements.txt (line 6))
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 51.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from lightning->-r requirements.txt (line 6)) (4.65.0)
# Requirement already satisfied: traitlets<7.0,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from lightning->-r requirements.txt (line 6)) (5.7.1)
# Requirement already satisfied: typing-extensions<6.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from lightning->-r requirements.txt (line 6)) (4.5.0)
# Requirement already satisfied: urllib3<3.0 in /usr/local/lib/python3.10/dist-packages (from lightning->-r requirements.txt (line 6)) (1.26.15)
# Collecting uvicorn<2.0 (from lightning->-r requirements.txt (line 6))
#   Downloading uvicorn-0.22.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: websocket-client<3.0 in /usr/local/lib/python3.10/dist-packages (from lightning->-r requirements.txt (line 6)) (1.5.1)
# Collecting websockets<12.0 (from lightning->-r requirements.txt (line 6))
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 15.5 MB/s eta 0:00:00
# Collecting pytorch-lightning (from lightning->-r requirements.txt (line 6))
#   Downloading pytorch_lightning-2.0.3-py3-none-any.whl (720 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 720.6/720.6 kB 54.3 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.10/dist-packages (from lightly->-r requirements.txt (line 7)) (2022.12.7)
# Collecting hydra-core>=1.0.0 (from lightly->-r requirements.txt (line 7))
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 19.3 MB/s eta 0:00:00
# Collecting lightly-utils~=0.0.0 (from lightly->-r requirements.txt (line 7))
#   Downloading lightly_utils-0.0.2-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from lightly->-r requirements.txt (line 7)) (2.8.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from lightly->-r requirements.txt (line 7)) (1.16.0)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.10/dist-packages (from lightly->-r requirements.txt (line 7)) (67.7.2)
# Collecting aenum>=3.1.11 (from lightly->-r requirements.txt (line 7))
#   Downloading aenum-3.1.12-py3-none-any.whl (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.8/131.8 kB 16.3 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from lightly->-r requirements.txt (line 7)) (0.15.2+cu118)
# Requirement already satisfied: astropy>=5.0.1 in /usr/local/lib/python3.10/dist-packages (from sunpy->-r requirements.txt (line 8)) (5.2.2)
# Collecting parfive[ftp]>=2.0.0 (from sunpy->-r requirements.txt (line 8))
#   Downloading parfive-2.0.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r requirements.txt (line 9)) (2022.7.1)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb->-r requirements.txt (line 10))
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 22.6 MB/s eta 0:00:00
# Collecting sentry-sdk>=1.0.0 (from wandb->-r requirements.txt (line 10))
#   Downloading sentry_sdk-1.25.1-py2.py3-none-any.whl (206 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.7/206.7 kB 21.6 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb->-r requirements.txt (line 10))
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools (from wandb->-r requirements.txt (line 10))
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle (from wandb->-r requirements.txt (line 10))
#   Downloading setproctitle-1.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb->-r requirements.txt (line 10)) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r requirements.txt (line 10)) (3.20.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->-r requirements.txt (line 11)) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->-r requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->-r requirements.txt (line 11)) (3.6.4)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->-r requirements.txt (line 11)) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->-r requirements.txt (line 11)) (3.0.7)
# Requirement already satisfied: pyerfa>=2.0 in /usr/local/lib/python3.10/dist-packages (from astropy>=5.0.1->sunpy->-r requirements.txt (line 8)) (2.0.0.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<6.0,>=4.8.0->lightning->-r requirements.txt (line 6)) (2.4.1)
# Collecting ordered-set<4.2.0,>=4.0.2 (from deepdiff<8.0,>=5.7.0->lightning->-r requirements.txt (line 6))
#   Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Collecting starlette (from lightning->-r requirements.txt (line 6))
#   Downloading starlette-0.22.0-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette->lightning->-r requirements.txt (line 6)) (3.6.2)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec<2024.0,>=2022.5.0->lightning->-r requirements.txt (line 6))
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 73.1 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 10))
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.0 MB/s eta 0:00:00
# Collecting omegaconf<2.4,>=2.2 (from hydra-core>=1.0.0->lightly->-r requirements.txt (line 7))
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 10.8 MB/s eta 0:00:00
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.0.0->lightly->-r requirements.txt (line 7))
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 15.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting blessed>=1.19.0 (from inquirer<5.0,>=2.10.0->lightning->-r requirements.txt (line 6))
#   Downloading blessed-1.20.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 7.7 MB/s eta 0:00:00
# Collecting python-editor>=1.0.4 (from inquirer<5.0,>=2.10.0->lightning->-r requirements.txt (line 6))
#   Downloading python_editor-1.0.4-py3-none-any.whl (4.9 kB)
# Collecting readchar>=3.0.6 (from inquirer<5.0,>=2.10.0->lightning->-r requirements.txt (line 6))
#   Downloading readchar-4.0.5-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 11)) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 11)) (6.3.1)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets->-r requirements.txt (line 11))
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 90.7 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->-r requirements.txt (line 11)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->-r requirements.txt (line 11)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->-r requirements.txt (line 11)) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->-r requirements.txt (line 11)) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->-r requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->-r requirements.txt (line 11)) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->-r requirements.txt (line 11)) (4.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2<5.0->lightning->-r requirements.txt (line 6)) (2.1.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from lightly-utils~=0.0.0->lightly->-r requirements.txt (line 7)) (8.4.0)
# Collecting pyjwt (from lightning-cloud>=0.5.34->lightning->-r requirements.txt (line 6))
#   Downloading PyJWT-2.7.0-py3-none-any.whl (22 kB)
# Collecting aioftp>=0.17.1 (from parfive[ftp]>=2.0.0->sunpy->-r requirements.txt (line 8))
#   Downloading aioftp-0.21.4-py3-none-any.whl (37 kB)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<4.0->lightning->-r requirements.txt (line 6)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<4.0->lightning->-r requirements.txt (line 6)) (3.4)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<15.0,>=12.3.0->lightning->-r requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: itsdangerous<3.0.0,>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from starsessions<2.0,>=1.2.1->lightning->-r requirements.txt (line 6)) (2.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=1.11.0->lightning->-r requirements.txt (line 6)) (3.12.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=1.11.0->lightning->-r requirements.txt (line 6)) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=1.11.0->lightning->-r requirements.txt (line 6)) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=1.11.0->lightning->-r requirements.txt (line 6)) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch<4.0,>=1.11.0->lightning->-r requirements.txt (line 6)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch<4.0,>=1.11.0->lightning->-r requirements.txt (line 6)) (16.0.5)
# Collecting h11>=0.8 (from uvicorn<2.0->lightning->-r requirements.txt (line 6))
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (6.4.8)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec<2024.0,>=2022.5.0->lightning->-r requirements.txt (line 6)) (23.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec<2024.0,>=2022.5.0->lightning->-r requirements.txt (line 6))
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 14.1 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec<2024.0,>=2022.5.0->lightning->-r requirements.txt (line 6))
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec<2024.0,>=2022.5.0->lightning->-r requirements.txt (line 6))
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 30.8 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec<2024.0,>=2022.5.0->lightning->-r requirements.txt (line 6))
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 19.4 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec<2024.0,>=2022.5.0->lightning->-r requirements.txt (line 6))
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette->lightning->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.10/dist-packages (from blessed>=1.19.0->inquirer<5.0,>=2.10.0->lightning->-r requirements.txt (line 6)) (0.2.6)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 10))
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->-r requirements.txt (line 11)) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<15.0,>=12.3.0->lightning->-r requirements.txt (line 6)) (0.1.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (5.3.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (5.8.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (0.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->-r requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch<4.0,>=1.11.0->lightning->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (3.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (21.2.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (4.9.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (0.7.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (4.3.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (0.19.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (1.15.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements.txt (line 11)) (2.21)
# Building wheels for collected packages: hits-sdo-packager, antlr4-python3-runtime, pathtools
#   Building wheel for hits-sdo-packager (setup.py) ... done
#   Created wheel for hits-sdo-packager: filename=hits_sdo_packager-0.1.0-py3-none-any.whl size=11283 sha256=1117f8e6b68591a04ee78e613b4dbe358502a3a4d19591520fd2a9ce17c3c77f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-bmt3znxn/wheels/2e/eb/6a/bd29fa0f13c312509ef59785fdf5297327b72cf53190878e91
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=c3ecc4b64edcf09d1eaef1df97fc3abd5edd581d71eb38d4510fe431923d904a
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=e9a3fb1cfb7ce2e449ee66252c49e9f22ac55f58c935d5ff914d6cd7a4d3f962
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built hits-sdo-packager antlr4-python3-runtime pathtools
# Installing collected packages: python-editor, pathtools, antlr4-python3-runtime, aenum, websockets, smmap, setproctitle, sentry-sdk, readchar, python-multipart, pyjwt, ordered-set, omegaconf, multidict, lightning-utilities, lightly-utils, jedi, hits-sdo-packager, h11, frozenlist, docker-pycreds, blessed, async-timeout, aioftp, yarl, uvicorn, starlette, inquirer, hydra-core, gitdb, deepdiff, dateutils, croniter, arrow, aiosignal, starsessions, GitPython, fastapi, aiohttp, wandb, parfive, lightning-cloud, sunpy, torchmetrics, pytorch-lightning, lightning, lightly
# Successfully installed GitPython-3.1.31 aenum-3.1.12 aioftp-0.21.4 aiohttp-3.8.4 aiosignal-1.3.1 antlr4-python3-runtime-4.9.3 arrow-1.2.3 async-timeout-4.0.2 blessed-1.20.0 croniter-1.3.15 dateutils-0.6.12 deepdiff-6.3.0 docker-pycreds-0.4.0 fastapi-0.88.0 frozenlist-1.3.3 gitdb-4.0.10 h11-0.14.0 hits-sdo-packager-0.1.0 hydra-core-1.3.2 inquirer-3.1.3 jedi-0.18.2 lightly-1.4.8 lightly-utils-0.0.2 lightning-2.0.3 lightning-cloud-0.5.36 lightning-utilities-0.8.0 multidict-6.0.4 omegaconf-2.3.0 ordered-set-4.1.0 parfive-2.0.2 pathtools-0.1.2 pyjwt-2.7.0 python-editor-1.0.4 python-multipart-0.0.6 pytorch-lightning-2.0.3 readchar-4.0.5 sentry-sdk-1.25.1 setproctitle-1.3.2 smmap-5.0.0 starlette-0.22.0 starsessions-1.3.0 sunpy-5.0.0 torchmetrics-0.11.4 uvicorn-0.22.0 wandb-0.15.4 websockets-11.0.3 yarl-1.9.2

# %% [markdown]
# ##  Load Modules

# %%
import copy
import numpy as np
from tqdm.autonotebook import tqdm

import torch
import torchvision
from torch import nn
import pytorch_lightning as pl
from pytorch_lightning.loggers import WandbLogger
torch.set_float32_matmul_precision("high")

import wandb
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.colors as colors
import matplotlib

from lightly.data import LightlyDataset
from lightly.data.multi_view_collate import MultiViewCollate
from lightly.loss import NegativeCosineSimilarity, NTXentLoss, TiCoLoss
from lightly.models.modules import BYOLPredictionHead, BYOLProjectionHead
from lightly.models.utils import deactivate_requires_grad, update_momentum
from lightly.transforms.simclr_transform import SimCLRTransform
from lightly.utils.scheduler import cosine_schedule

from search_byol.dataset import SDOTilesDataset

device = "cuda" if torch.cuda.is_available() else "cpu"
# Out:
# <ipython-input-9-4f08b17ac873>:3: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %% [markdown]
# ## Login to Wanddb and initialize logger

# %%
# !wandb login --relogin
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %% [markdown]
# ## Define run parameters and initalize Wandb

# %%
# Set data type and data path.  Make sure it matches cells above

# 171 with false yellow colors
# data_type = '171Color'
# data_path = '/content/aia_171_color_1perMonth'

# 171 grayscale
# data_type = '171gray'
# data_path = '/content/AIA171_Miniset_BW'

# Multiwavelength r:211 g:193 b:171
# data_type = 'r:211 g:193 b:171'
data_type = 'r:211 g:193 b:171 extended'
data_path = '/content/AIA211_193_171_Miniset'

# Multiwavelength r:304 g:211 b:171
# data_type = 'r:304 g:211 b:171'
# data_type = 'r:304 g:211 b:171 extended'
# data_path = '/content/AIA304_211_171_Miniset'

# Multiwavelength r:335 g:193 b:94
# data_type = 'r:335 g:193 b:94'
# data_type = 'r:335 g:193 b:94 extended'
# data_path = '/content/AIA335_193_94_Miniset'

# %%
seed = 42
pl.seed_everything(seed, workers=True)

initial = "JLC"
job_type = "JLC"
epochs = 4
data_stride = 10
batch_size = 128
augmentation = 'double'
loss = 'tico'         # 'tico' or 'cos'
learning_rate = 0.1
cosine_scheduler_start = .1
cosine_scheduler_end = 1.0
projection_size = 2
prediction_size = 2

notes = "Commit message first experimentation run one"
name = f"{initial}-ds{data_stride}_bs{batch_size}_lr{learning_rate}_{augmentation}aug_ss{cosine_scheduler_start}_se{cosine_scheduler_end}_pjs{projection_size}_pds{prediction_size}_{loss}"
group = "pl"
tags = ["experimentation"]


wandb_logger = WandbLogger(
    # set the wandb project where this run will be logged
    project="search-byol-for_real",

    # track hyperparameters and run metadata
    config={
    "seed": seed,
    "data_type": data_type,
    "batch size": batch_size,
    "augmention": augmentation,
    "data stride": data_stride,
    "learning_rate": learning_rate,
    "cosine_scheduler_start": cosine_scheduler_start,
    "cosine_scheduler_end": cosine_scheduler_end
    },
    entity = "search-byol",
    job_type = job_type,
    name = name,
    notes = notes,
    group = group,
    tags = tags,

)
# Out:
# INFO:lightning_fabric.utilities.seed:Global seed set to 42
# wandb: Currently logged in as: amunozj (search-byol). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.15.4
# Run data is saved locally in <code>./wandb/run-20230615_214529-fh93qbuh</code>
# Syncing run <strong><a href='https://wandb.ai/search-byol/search-byol-for_real/runs/fh93qbuh' target="_blank">AMJ-ds10_bs128_lr0.1_doubleaug_ss0.1_se1.0_pjs2_pds2_contrast</a></strong> to <a href='https://wandb.ai/search-byol/search-byol-for_real' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/search-byol/search-byol-for_real' target="_blank">https://wandb.ai/search-byol/search-byol-for_real</a>
#  View run at <a href='https://wandb.ai/search-byol/search-byol-for_real/runs/fh93qbuh' target="_blank">https://wandb.ai/search-byol/search-byol-for_real/runs/fh93qbuh</a>

# %% [markdown]
# ## Define BYOL Model

# %%
class BYOL(pl.LightningModule):
    def __init__(self, lr=0.1, projection_size=256, prediction_size=256, cosine_scheduler_start=0.1, cosine_scheduler_end=1.0, epochs=10, loss='cos'):
        super().__init__()

        resnet = torchvision.models.resnet18()
        self.backbone = nn.Sequential(*list(resnet.children())[:-1])
        self.projection_head = BYOLProjectionHead(512, 1024, projection_size)
        self.prediction_head = BYOLPredictionHead(projection_size, 1024, prediction_size)

        self.backbone_momentum = copy.deepcopy(self.backbone)
        self.projection_head_momentum = copy.deepcopy(self.projection_head)

        deactivate_requires_grad(self.backbone_momentum)
        deactivate_requires_grad(self.projection_head_momentum)


        self.loss = loss
        self.loss_cos = NegativeCosineSimilarity()
        self.loss_tico = TiCoLoss()

        self.cosine_scheduler_start = cosine_scheduler_start
        self.cosine_scheduler_end = cosine_scheduler_end
        self.epochs = epochs
        self.lr = lr

    def forward(self, x):
        y = self.backbone(x).flatten(start_dim=1)
        z = self.projection_head(y)
        p = self.prediction_head(z)
        return p

    def forward_momentum(self, x):
        y = self.backbone_momentum(x).flatten(start_dim=1)
        z = self.projection_head_momentum(y)
        z = z.detach()
        return z

    def training_step(self, batch, batch_idx):
        momentum = cosine_schedule(self.current_epoch, self.epochs, self.cosine_scheduler_start, self.cosine_scheduler_end)
        update_momentum(self.backbone, self.backbone_momentum, m=momentum)
        update_momentum(self.projection_head, self.projection_head_momentum, m=momentum)
        (x0, x1) = batch
        p0 = self.forward(x0)
        z0 = self.forward_momentum(x0)
        p1 = self.forward(x1)
        z1 = self.forward_momentum(x1)


        loss_cos = 0.5 * (self.loss_cos(p0, z1) + self.loss_cos(p1, z0))
        loss_tico = 0.5 * (self.loss_tico(p0, z1) + self.loss_tico(p1, z0))

        if self.loss == 'cos':
            loss = loss_cos
        else:
            loss = loss_contrast

        self.log('loss cos', loss_cos)
        self.log('loss contrast', loss_contrast)
        self.log('loss', loss)
        return loss

    def configure_optimizers(self):
        return torch.optim.SGD(self.parameters(), lr=self.lr)

# %% [markdown]
# ## Initialize Module

# %%
model = BYOL(lr=learning_rate, projection_size=projection_size, prediction_size=prediction_size, cosine_scheduler_start=cosine_scheduler_start, cosine_scheduler_end=cosine_scheduler_end, loss=loss)

# %% [markdown]
# ## Initialize Dataloader

# %%
dataset = SDOTilesDataset(data_path=data_path, augmentation=augmentation, data_stride=data_stride)

dataloader = torch.utils.data.DataLoader(
    dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=False,
    num_workers=8,
)

# %% [markdown]
# ## Run Training Loop, Inference, and log in wandb

# %%
trainer = pl.Trainer(max_epochs=epochs,
                     accelerator="auto", devices="auto", strategy="auto",
                     logger=wandb_logger, log_every_n_steps=10, deterministic=True)

wandb_logger.watch(model)
trainer.fit(model=model, train_dataloaders=dataloader)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# wandb: logging graph, to disable use `wandb.watch(log_graph=False)`
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name                     | Type                     | Params
# ----------------------------------------------------------------------
# 0 | backbone                 | Sequential               | 11.2 M
# 1 | projection_head          | BYOLProjectionHead       | 528 K
# 2 | prediction_head          | BYOLPredictionHead       | 6.1 K
# 3 | backbone_momentum        | Sequential               | 11.2 M
# 4 | projection_head_momentum | BYOLProjectionHead       | 528 K
# 5 | loss_cos                 | NegativeCosineSimilarity | 0
# 6 | loss_contrast            | NTXentLoss               | 0
# ----------------------------------------------------------------------
# 11.7 M    Trainable params
# 11.7 M    Non-trainable params
# 23.4 M    Total params
# 93.664    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=4` reached.

# %% [markdown]
# ### Save model to wandb

# %%
# torch.save(model.state_dict(), f'{name}_.pt')
# wandb.save(f'{name}_.pt')

# %% [markdown]
# ## Run inference

# %%
dataset_inference = SDOTilesDataset(data_path=data_path, augmentation='none', data_stride=10)

dataloader_inference = torch.utils.data.DataLoader(
    dataset_inference,
    batch_size=1000,
    shuffle=True,
    drop_last=False,
    num_workers=8,
)

batches_bar = tqdm(dataloader_inference, dynamic_ncols=True, leave=True, desc=f'Running inference on batches')


model.to(device)
inference_list = []
for (x0, x1) in batches_bar:
    embeddings_inference = model.forward_momentum(x0.to(device)).cpu().numpy()
    inference_list.append(embeddings_inference)

embeddings_inference = np.concatenate(inference_list, axis=0)
# Out:
# Running inference on batches:   0%|          | 0/28 [00:00<?, ?it/s]

# %%
x1 = torch.tensor(inference_list[0])
x2 = torch.tensor(inference_list[-1])

torch.tanh(torch.cdist(x1, x2, p=2.0)).mean()
# Out:
# tensor(0.9831)

# %% [markdown]
# ## Plot Embeddings

# %%
fig = plt.figure(figsize=[6,3], layout='constrained', dpi=300)
spec = gridspec.GridSpec(ncols=2, nrows=1, figure=fig)

# Scatter plot
ax1 = fig.add_subplot(spec[0, 0])
color=matplotlib.colors.colorConverter.to_rgba('mediumseagreen', alpha=.1)
ax1.plot(embeddings_inference[:,0], embeddings_inference[:,1], 'o', markersize=1, alpha=0.1, color=color, markeredgecolor=color, linewidth=0)
ax1.set_title('Scatter plot')

# 2D histogram
ax2 = fig.add_subplot(spec[0, 1])
histout = np.histogram2d(embeddings_inference[:,0], embeddings_inference[:,1], bins=50)
ax2.hist2d(embeddings_inference[:,0], embeddings_inference[:,1], bins=100, cmap=plt.cm.magma_r, vmax=np.percentile(histout[0], 99))
ax2.set_title('2D histogram');

# %% [markdown]
# ## Send figure to wandb and finish run

# %%
wandb.log({"Embeddings": wandb.Image(fig)})
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.488 MB of 0.647 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.754072…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▁▁▁▁▃▃▃▃▃▃▃▃▃▃▆▆▆▆▆▆▆▆▆▆██████████</td></tr><tr><td>loss</td><td>█▃▂▂▃▃▃▂▂▂▂▃▁▃▁▃▁▃▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▂▁▁</td></tr><tr><td>loss contrast</td><td>█▃▂▂▃▃▃▂▂▂▂▃▁▃▁▃▁▃▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▂▁▁</td></tr><tr><td>loss cos</td><td>█▄▃▂▃▂▄▂▃▁▃▄▂▅▂▄▂▄▁▃▁▂▂▂▂▂▁▂▂▁▂▂▁▂▁▂▃▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>3</td></tr><tr><td>loss</td><td>4.50145</td></tr><tr><td>loss contrast</td><td>4.50145</td></tr><tr><td>loss cos</td><td>-0.97957</td></tr><tr><td>trainer/global_step</td><td>859</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">AMJ-ds10_bs128_lr0.1_doubleaug_ss0.1_se1.0_pjs2_pds2_contrast</strong> at: <a href='https://wandb.ai/search-byol/search-byol-for_real/runs/fh93qbuh' target="_blank">https://wandb.ai/search-byol/search-byol-for_real/runs/fh93qbuh</a><br/>Synced 5 W&B file(s), 2 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230615_214529-fh93qbuh/logs</code>
